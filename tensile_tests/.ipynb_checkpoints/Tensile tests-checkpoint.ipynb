# %%
#!pip3 install pandas
#!pip3 install seaborn

# %matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
#import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Tensile test data.csv', header = 0)
df.groupby('Description')[['XY Strength (MPa)', 'Z Strength (MPa)']].describe()
# Out:
#                             XY Strength (MPa)                                 \
#                                         count   mean       std    min    25%
# Description
# 3D Solutech PLA (black)                   5.0  65.14  2.248722  61.80  63.85
# 3D Solutech PLA+CF (black)                5.0  59.51  2.130552  57.25  57.65
# Overture PLA (matte black)                5.0  36.71  1.174415  35.20  36.25
# PolyTerra PLA (matte black)               5.0  32.81  0.489132  32.15  32.55
# Prusa PETG (orange)                       5.0  52.92  2.241818  50.10  51.35
#
#                                                  Z Strength (MPa)          \
#                                50%    75%    max            count    mean
# Description
# 3D Solutech PLA (black)      66.45  66.50  67.10              0.0     NaN
# 3D Solutech PLA+CF (black)   60.00  60.15  62.50              5.0  11.628
# Overture PLA (matte black)   36.50  37.25  38.35              5.0  10.180
# ...

# %%
df[df['Description']=='Overture PLA (matte black)']['Z Strength (MPa)'].std()
# Out:
# 2.258959937670432
