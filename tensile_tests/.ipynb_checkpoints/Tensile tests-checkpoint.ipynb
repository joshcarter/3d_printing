# %%
#!pip3 install pandas
#!pip3 install seaborn

# %matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
#import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Tensile test data.csv', header = 0)
df.groupby('Description')[['XY Strength (MPa)', 'Z Strength (MPa)']].describe()
# Out:
#                                   XY Strength (MPa)                          \
#                                               count   mean       std    min
# Description
# 3D Solutech PLA (black)                         5.0  65.14  2.248722  61.80
# 3D Solutech PLA+CF (black)                      5.0  59.51  2.130552  57.25
# Overture PLA (matte black)                      5.0  36.71  1.174415  35.20
# PolyTerra PLA (matte black)                     5.0  32.81  0.489132  32.15
# Polymaker PA6-CF (black)                        5.0  67.99  1.248699  66.50
# Polymaker PA6-CF annealed (black)               5.0  71.89  2.585392  68.05
# Prusa PETG (orange)                             5.0  52.92  2.241818  50.10
#
#                                                                \
#                                      25%    50%    75%    max
# Description
# 3D Solutech PLA (black)            63.85  66.45  66.50  67.10
# 3D Solutech PLA+CF (black)         57.65  60.00  60.15  62.50
# Overture PLA (matte black)         36.25  36.50  37.25  38.35
# PolyTerra PLA (matte black)        32.55  32.90  33.00  33.45
# Polymaker PA6-CF (black)           67.55  67.60  68.45  69.85
# Polymaker PA6-CF annealed (black)  70.55  72.75  73.80  74.30
# Prusa PETG (orange)                51.35  53.15  54.30  55.70
#
#                                   Z Strength (MPa)                           \
#                                              count    mean       std    min
# Description
# 3D Solutech PLA (black)                        0.0     NaN       NaN    NaN
# 3D Solutech PLA+CF (black)                     5.0  11.628  5.767358   5.07
# Overture PLA (matte black)                     5.0  10.180  2.258960   6.77
# PolyTerra PLA (matte black)                    0.0     NaN       NaN    NaN
# Polymaker PA6-CF (black)                       5.0   8.892  0.825148   8.00
# Polymaker PA6-CF annealed (black)              5.0   7.126  0.724141   6.50
# Prusa PETG (orange)                            5.0  16.798  4.417541  11.63
#
#
#                                      25%    50%    75%    max
# Description
# 3D Solutech PLA (black)              NaN    NaN    NaN    NaN
# 3D Solutech PLA+CF (black)          6.67  11.77  16.70  17.93
# Overture PLA (matte black)          9.70  10.03  11.77  12.63
# PolyTerra PLA (matte black)          NaN    NaN    NaN    NaN
# Polymaker PA6-CF (black)            8.10   9.13   9.30   9.93
# Polymaker PA6-CF annealed (black)   6.63   6.70   7.70   8.10
# Prusa PETG (orange)                13.60  17.80  17.93  23.03

# %%
df[df['Description']=='Overture PLA (matte black)']['Z Strength (MPa)'].std()
# Out:
# 2.258959937670432
